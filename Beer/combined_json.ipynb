# %%
import pandas as pd
import json
import glob

# %%
pg1 = pd.read_json("Resources/beerspg1.json")
df_pg1 = pd.DataFrame(pg1)
df_pg1
# Out:
#       abv  attenuation_level                      boil_volume  \
# 0    4.50              75.00  {'value': 25, 'unit': 'litres'}
# 1    4.10              76.00  {'value': 25, 'unit': 'litres'}
# 2    4.20              83.00  {'value': 25, 'unit': 'litres'}
# 3    6.30              80.00  {'value': 25, 'unit': 'litres'}
# 4    7.20              67.00  {'value': 25, 'unit': 'litres'}
# 5    5.20              88.90  {'value': 25, 'unit': 'litres'}
# 6   11.20              84.00  {'value': 25, 'unit': 'litres'}
# 7    4.70              78.00  {'value': 25, 'unit': 'litres'}
# 8   12.50              83.00  {'value': 25, 'unit': 'litres'}
# 9    7.50              80.90  {'value': 25, 'unit': 'litres'}
# 10   7.30              74.70  {'value': 25, 'unit': 'litres'}
# 11   5.30              77.00  {'value': 25, 'unit': 'litres'}
# 12   4.50              74.50  {'value': 25, 'unit': 'litres'}
# 13   4.50              72.80  {'value': 25, 'unit': 'litres'}
# ...

# %%
pg2 = pd.read_json("Resources/beerspg2.json")
df_pg2 = pd.DataFrame(pg2)
df_pg2
# Out:
#      abv  attenuation_level                      boil_volume  \
# 0    4.4               79.5  {'value': 25, 'unit': 'litres'}
# 1    6.3               82.6  {'value': 25, 'unit': 'litres'}
# 2    7.2               82.1  {'value': 25, 'unit': 'litres'}
# 3    3.6               88.0  {'value': 25, 'unit': 'litres'}
# 4    4.5               72.9  {'value': 25, 'unit': 'litres'}
# 5    7.8               83.2  {'value': 25, 'unit': 'litres'}
# 6    4.5               75.6  {'value': 25, 'unit': 'litres'}
# 7    6.3               80.0  {'value': 25, 'unit': 'litres'}
# 8    7.5               82.1  {'value': 25, 'unit': 'litres'}
# 9   10.0               79.6  {'value': 25, 'unit': 'litres'}
# 10   3.8               70.0  {'value': 25, 'unit': 'litres'}
# 11  11.6               80.0  {'value': 25, 'unit': 'litres'}
# 12   6.4               87.0  {'value': 25, 'unit': 'litres'}
# 13  10.5               93.8  {'value': 25, 'unit': 'litres'}
# ...

# %%
combined_pg = df_pg1.append(df_pg2)
combined_pg
# Out:
#       abv  attenuation_level                      boil_volume  \
# 0    4.50               75.0  {'value': 25, 'unit': 'litres'}
# 1    4.10               76.0  {'value': 25, 'unit': 'litres'}
# 2    4.20               83.0  {'value': 25, 'unit': 'litres'}
# 3    6.30               80.0  {'value': 25, 'unit': 'litres'}
# 4    7.20               67.0  {'value': 25, 'unit': 'litres'}
# 5    5.20               88.9  {'value': 25, 'unit': 'litres'}
# 6   11.20               84.0  {'value': 25, 'unit': 'litres'}
# 7    4.70               78.0  {'value': 25, 'unit': 'litres'}
# 8   12.50               83.0  {'value': 25, 'unit': 'litres'}
# 9    7.50               80.9  {'value': 25, 'unit': 'litres'}
# 10   7.30               74.7  {'value': 25, 'unit': 'litres'}
# 11   5.30               77.0  {'value': 25, 'unit': 'litres'}
# 12   4.50               74.5  {'value': 25, 'unit': 'litres'}
# 13   4.50               72.8  {'value': 25, 'unit': 'litres'}
# ...

# %%
pg3 = pd.read_json("Resources/beerspg3.json")
df_pg3 = pd.DataFrame(pg3)
df_pg3
# Out:
#      abv  attenuation_level                      boil_volume  \
# 0   13.2              82.17  {'value': 25, 'unit': 'litres'}
# 1    4.9              80.70  {'value': 25, 'unit': 'litres'}
# 2    4.7              83.70  {'value': 25, 'unit': 'litres'}
# 3    7.2              84.00  {'value': 25, 'unit': 'litres'}
# 4   10.0              79.40  {'value': 25, 'unit': 'litres'}
# 5    4.5              73.90  {'value': 25, 'unit': 'litres'}
# 6    7.2              78.60  {'value': 25, 'unit': 'litres'}
# 7    7.2              84.60  {'value': 25, 'unit': 'litres'}
# 8   13.1                NaN  {'value': 25, 'unit': 'litres'}
# 9    9.7              83.00  {'value': 25, 'unit': 'litres'}
# 10   6.7              79.70  {'value': 25, 'unit': 'litres'}
# 11   5.0              78.00  {'value': 25, 'unit': 'litres'}
# 12   7.2              84.00  {'value': 25, 'unit': 'litres'}
# 13   4.4              82.90  {'value': 25, 'unit': 'litres'}
# ...

# %%
pg4 = pd.read_json("Resources/beerspg4.json")
df_pg4 = pd.DataFrame(pg4)

pg5 = pd.read_json("Resources/beerspg5.json")
df_pg5 = pd.DataFrame(pg5)

# %%
combined_pg = combined_pg.append(df_pg3)
combined_pg = combined_pg.append(df_pg4)
combined_pg = combined_pg.append(df_pg5)
combined_pg
# Out:
#       abv  attenuation_level                      boil_volume  \
# 0    4.50               75.0  {'value': 25, 'unit': 'litres'}
# 1    4.10               76.0  {'value': 25, 'unit': 'litres'}
# 2    4.20               83.0  {'value': 25, 'unit': 'litres'}
# 3    6.30               80.0  {'value': 25, 'unit': 'litres'}
# 4    7.20               67.0  {'value': 25, 'unit': 'litres'}
# 5    5.20               88.9  {'value': 25, 'unit': 'litres'}
# 6   11.20               84.0  {'value': 25, 'unit': 'litres'}
# 7    4.70               78.0  {'value': 25, 'unit': 'litres'}
# 8   12.50               83.0  {'value': 25, 'unit': 'litres'}
# 9    7.50               80.9  {'value': 25, 'unit': 'litres'}
# 10   7.30               74.7  {'value': 25, 'unit': 'litres'}
# 11   5.30               77.0  {'value': 25, 'unit': 'litres'}
# 12   4.50               74.5  {'value': 25, 'unit': 'litres'}
# 13   4.50               72.8  {'value': 25, 'unit': 'litres'}
# ...

# %%
combined_pg.to_csv('combined_csv', sep='\t', encoding='utf-8')
